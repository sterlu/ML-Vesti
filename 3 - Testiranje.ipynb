# %%
# !pip install transformers tokenizers datasets
# Out:
# Requirement already satisfied: transformers in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: tokenizers in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (0.10.3)
# Requirement already satisfied: datasets in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: requests in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (2.25.1)
# Requirement already satisfied: sacremoses in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: packaging in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (20.9)
# Requirement already satisfied: tqdm>=4.27 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (4.49.0)
# Requirement already satisfied: pyyaml in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: filelock in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: huggingface-hub==0.0.12 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from transformers) (0.0.12)
# Requirement already satisfied: typing-extensions in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: pandas in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (1.2.4)
# Requirement already satisfied: dill in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (0.3.4)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: xxhash in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: fsspec in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (2021.6.1)
# Requirement already satisfied: multiprocess in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from requests->transformers) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: joblib in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /Users/sterlu/opt/miniconda3/envs/ml/lib/python3.9/site-packages (from sacremoses->transformers) (8.0.1)

# %%
input_filename = "naslovi.input"
dataset_filename = input_filename + '.prepared'
pretrained_model_name = 'distilgpt2'
new_model_name = pretrained_model_name + '_3'

# %%
import sys
in_colab = 'google.colab' in sys.modules
model_dir = '/content/drive/My Drive/modeli/' if in_colab else './modeli/'

# %%
from transformers import PreTrainedTokenizerFast
tokenizer = PreTrainedTokenizerFast(tokenizer_file=model_dir + new_model_name + "/tokenizer.json")
tokenizer.pad_token = "<pad>"

import numpy as np
from transformers import AutoModelForCausalLM, AutoModelForMaskedLM

model = AutoModelForCausalLM.from_pretrained(model_dir + new_model_name)
model.config.pad_token_id = 1

for temp in np.linspace(0.2, 2, 10):
    print()
    print("###### Temperature: " + str(temp))
    for i in range(0, 5):
        out = model.generate(do_sample=True, temperature=temp)[0]
        print(tokenizer.decode(out, skip_special_tokens=True))
# Out:
# ###### Temperature: 0.2
# U Srbiji se ne zna ko je bio na početku karijere
# U Srbiji se ne zna ko je bio na kraju dan
# Evo šta je rekao o tome i šta je rekla o tome!
# U toku je velika akcijačka stanica, a evo šta je sve potrebno je
# U Beogradu.005.009.005.007 dinara za evro
#
# ###### Temperature: 0.4
# Evo šta se zaista desilo sa kim se dešavalio!
# Evo kako je izgledao čovek koji je u pitanju!
# Evo kako da se zaštititete, a da li ste ste ste se ponašate?
# A evo šta sve možete da uradite ZAMOVEPEREŠSE  Evo šta je rekao
# U Srbiji je sve spremno priznanje za Srbiju-belenovacnovacnovac Palmanovac
#
# ###### Temperature: 0.6000000000000001
# Ovo je nova žrtva fotografije supruge žena, a ne mogu da se vratiče! (FOTO)
# S zbog čega je novi trener Partizana postao pokramice!
# U Beogradu počinje izgradnja službeke i po dva sata, a evo kako će izgledati moći će biti
# Evo šta je rekao o svom dečku, a onda se u kakvom stanju stanju IZDANJU je nastao MUK
# Evo šta se dešava u Srbiji, a tek kad saznate je rečnih i dalje je to ISTINA
#
# ###### Temperature: 0.8
# Maskag ekipaka je bio herojnica savezaska vladava, a onda je na nju
# Rehabilisni podaci na aerodromusku Beograd
# Novi Sad je dobila od straha vremena, a evo šta može da joj se desi!
# Vučić  Prekići, ali je bilo jedan dan od najvećih epidemije opreme
# Nakon što je u vezi sa Šamomćem problemima pa se zabarikažilirio
#
# ###### Temperature: 1.0
# U Beogradu je tri godine ljudi koji su počeli da će ih na osnovu slici
# Prelegli pomoć serijskog premijera, a sad je i koliko su se i svi su
# Na dan ažnokovatinag  Preletadacano, ali šta to je prava
# Posle ubistva poruka reakcija je u redu akrostolja!
# Ovako su se sastalili brod Laćeskog klubagena (VIDEO)
#
# ###### Temperature: 1.2
# A sad je uradio šok na plaži, kada sam u suzama je ušla!
# U Beogradu. godini 520 novih.000 dinara se traga bore od osnivanja Monsijan
# Svi Srbi imaju simptome vrednosti nedelje na svetu  Nije tačno da vam se dobro do sada i da
# Pogledajte kako je devojka učesnica TomovićaVAO ćerki IZDATIO detalje
# Novi Sad dao nova pravila o zdravstvenom stanjutunim temamačkom mestukom životu
#
# ###### Temperature: 1.4000000000000001
# Predsednik Rusije uručio spot Petrovićaburg za ljudska prava na svetu! Izrepiničničkom putu
# Izvozlnijih pravila u Blicunoj krizitama Beograda godine zatvora! Nema njima! Upo
# Vučić dobio je od najboljihčnustičkeljenjem partijejskojsko pomoćnicunske kompanijebina igara
# Iz Evrope, građani bi mogla bili još u vezi vlastima na Balkanu-vrmerima
# Azatvocske porodice Volstriđana suda i Miškovića o kandidaznoj organimacijamaskoj
#
# ###### Temperature: 1.6
# Šta možete pogoditi istina o tome zdravljeMKIJUSTAPISANECIJI BOMSTAGUROM
# Kada ćeš je mojašrio samo suflumeli uz ime u Srbiji ili... (
# U utorak 2018kupu prvenstva nastavljačuje partnercima
# Skrana će biti u Beogradunju mera
# Evo ko su najvažnije nacionalne banka Zvezde pred novinarima zbog koronavirusanog toka ostrvaestourutorunih snaga
#
# ###### Temperature: 1.8
# Za dve saobraćajke grada  Jatakovarinkom! Prošloću od 100 dinara i penzija
# Ovo ste malo, nego ikad će iznenaditi ravnodušnimDITIŠNJETTA i da neće proći
# Na proleće dve godine!
# Mišavićeva sin  Samoj njemu mervrkao! OVO SEDEDIJU
# Šta je, neka će je uvek biti do 2020 časova vakcina i biti! Da neće statipiti
#
# ###### Temperature: 2.0
# Dr Bogdanović Ćugalić, Ivan Stojković Pokerović pokazao HAOSNU TAJNU VESTICUNICISKI
# Svečana srpskih zajednica u Zagrebu! Dolazim o izborima živodenici iz snovaBRDtika
# Kada i ovo možete pronaći! Izlist ne žele slučaj u Srbijurku, a pogledajte šta
# Da nema sa suprugom liste
# Predsednik Vučić idet o imenu redu smrti princa Guduktora Kagičenko Savićčića
